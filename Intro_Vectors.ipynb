# %% [markdown]
# 1. Let u = (1, -2, 4) and v = (3, 5, 1) w = (2, 1, -3)
# Manual

# %% [markdown]
# a. 3u - 2v
# =  3u - 2v = 3(1, -2, 4) - 2(3, 5, 1)
# =  (3, -6, 12) - (6, 10, 2)
# = (-3, -16, 10)
#
# b. 5u + 3v - 4w
# =  5(1, -2, 4) + 3(3, 5, 1) - 4(2, 1, -3)
# = (5, -10, 20) + (9, 15, 3) - (8, 4, -12)
# = (6, 1, 35)
#
# c. u · v, v · w, u · w
# u · v = 1(3) - 2(5) + 4(1) = -3
# v · w = 3(2) + 5(1) + 1(-3) = 8
# u · w = 1(2) - 2(1) + 4(-3) = -12
#
# d. ||u||, ||v||, ||w||
# ||u|| = $\sqrt{u · u}$ = $\sqrt{1^{2}+(-2)^{2}+4^{2}}$ = $\sqrt{21}$
# ||v|| = $\sqrt{v · v}$ = $\sqrt{3^{2}+5^{2}+1^{2}}$ = $\sqrt{35}$
# ||w|| = $\sqrt{w · w}$ = $\sqrt{2^{2}+1^{2}+(-3)^{2}}$ = $\sqrt{14}$
#
# e. If $\theta$ is the angle between u and v, find cos$\theta$
# = cos$\theta$ = $\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}|| \ ||\textbf{v}||}$
# $=\frac{1(3)-2(5)+4(1)}{\sqrt{1^{2}+(-2)^{2}+4^{2}}\sqrt{3^{2}+5^{2}+1^{2}}}$
# $=-\frac{3}{\sqrt{21}\sqrt{35}}$
#
# f. If $\alpha$ is the angle between v and w, find cos$\alpha$
# = cos$\alpha$ = $\frac{\textbf{v} \cdotp \textbf{w}}{||\textbf{v}|| \ ||\textbf{w}||}$
# $=\frac{3(2)+5(1)+1(-3)}{\sqrt{3^{2}+5^{2}+1^{2}}\sqrt{2^{2}+1^{2}+(-3)^{2}}}$
# $=\frac{8}{\sqrt{35}\sqrt{14}}$
#
# g. If $\beta$ is the angle between u and w, find cos$\beta$
# = cos$\beta$ = $\frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{u}|| \ ||\textbf{w}||}$
# $=\frac{1(2)-2(1)+4(-3)}{\sqrt{1^{2}+(-2)^{2}+4^{2}}\sqrt{2^{2}+1^{2}+(-3)^{2}}}$
# $=-\frac{12}{\sqrt{21}\sqrt{14}}$
#
# h. Find d(u, v)
# d(u, v) = ||u - v|| = $\sqrt{(1-3)^2 + (-2-5)^2 + (4-1)^2} = \sqrt{4+49+9} = \sqrt{62}$
#
# i. Find d(w, v)
# d(w, v) = || w -v || = $\sqrt{(2-3)^2 + (1-5)^2 + (-3-1)^2} = \sqrt{1+16+16} = \sqrt{33}$
#
# j. Find d(u, w)
# d(u, w) = ||u - w|| = $\sqrt{(1-2)^2 + (-2-1)^2 + (4-(-3))^2} = \sqrt{1+9+49} = \sqrt{59}$
#
# k. Find proj(u, v)
# proj(u, v) = $\frac{u · v}{||v||^2} {v} = \frac{-3}{(\sqrt{35})^2}(3,5,1) =-\frac{3}{35}(3,5,1) = (-\frac{9}{35},-\frac{15}{35},-\frac{3}{35})$
#
# l. Find proj(w, v)
# proj(w, v) = $\frac{w · v}{||v||^2} v = \frac{8}{(\sqrt{35})^2}(3,5,1) =\frac{8}{35}(3,5,1) = (\frac{32}{35},\frac{8}{7},\frac{8}{35})$
#
# m. Find proj(u, w)
# proj(u, w) = $\frac{u · w}{||w||^2} w = \frac{-12}{(\sqrt{14})^2}(2,1,-3) =\frac{-12}{14}(2,1,-3) = -\frac{6}{7}(2,1,-3) = (-\frac{12}{7},-\frac{6}{7},\frac{18}{7})$

# %% [markdown]
# Pythonic Solution:

# %%
import numpy as np

u = np.array([1, -2, 4])
v = np.array([3, 5, 1])
w = np.array([2, 1, -3])

print("a. 3u - 2v =  ", (3*u) - (2*v))

print("b. 5u + 3v -4w = ", (5*u) + (3*v) - (4*w))

print("c. u · v, v · w, u · w = ", u.dot(v),", ", v.dot(w),", ", u.dot(w))

print("d. ||u||, ||v||, ||w|| = ", np.sqrt(u.dot(u)),", ", np.sqrt(v.dot(v)),", ", np.sqrt(w.dot(w)))

print("e. cosθ = (u · v) =  ", u.dot(v) / (np.linalg.norm(u) * np.linalg.norm(v)))

print("f. cosα = (v · w) =  ", v.dot(w) / (np.linalg.norm(v) * np.linalg.norm(w)))

print("g. cosβ = (u · w) =  ", u.dot(w) / (np.linalg.norm(u) * np.linalg.norm(w)))

print("h. d(u,v) = ", np.linalg.norm(u-v))

print("i. d(w,v) = ", np.linalg.norm(w-v))

print("j. d(u,w) = ", np.linalg.norm(u-w))

print("k. proj(u, v) = ", u.dot(v)*v/(np.linalg.norm(v)**2))

print("l. proj(w, v) = ", w.dot(v)*v/(np.linalg.norm(v)**2))

print("m. proj(u, w) = ", u.dot(w)*w/(np.linalg.norm(w)**2))

# %% [markdown]
# 2. Repeat problem 1 with the following column vectors:
# \begin{align}
#     \textbf{u} &= \begin{bmatrix}
#            1 \\
#            3 \\
#            -4
#          \end{bmatrix}, \textbf{v} = \begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix}, \textbf{w} = \begin{bmatrix}
#            3 \\
#            -2 \\
#            6
#          \end{bmatrix}
#   \end{align}
# Manual

# %% [markdown]
# a. 3u - 2v
# = 3u - 2v = 3(1, 3, -4) - 2(2, 1, 5)
# = (3, 9, 12) - (4, 2, 10)
# = (-1, -7, 2)
#
# b. 5u + 3v - 4w
# =  5(1, 3, -4) + 3(2, 1, 5) - 4(3, -2, 6)
# = (5, 15, -20) + (6, 3, 15) - (12, -8, 24)
# = (-1, 26, -29)
#
# c. u · v, v · w, u · w
# u · v = 1(2) + 3(1) - 4(5) = -15
# v · w = 2(3) + 1(-2) + 5(6) = 34
# u · w = 1(3) + 3(-2) - 4(6) = -27
#
# d. ||u||, ||v||, ||w||
# ||u|| = $\sqrt{u · u}$ = $\sqrt{1^{2}+(3)^{2}+(-4)^{2}}$ = $\sqrt{26}$
# ||v|| = $\sqrt{v · v}$ = $\sqrt{2^{2}+1^{2}+5^{2}}$ = $\sqrt{30}$
# ||w|| = $\sqrt{w · w}$ = $\sqrt{3^{2}+(-2)^{2}+6^{2}}$ = $\sqrt{49} = 7$
#
# e. If $\theta$ is the angle between u and v, find $\cos{\theta}$
# = cos$\theta$ = $\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}|| \ ||\textbf{v}||}$
# $=\frac{1(2)+3(1)-4(5)}{\sqrt{1^{2}+3^{2}+(-4)^{2}}\sqrt{2^{2}+1^{2}+5^{2}}}$
# $=-\frac{15}{2\sqrt{195}}$
#
# f. If $\alpha$ is the angle between v and w, find cos$\alpha$
# = cos$\alpha$ = $\frac{\textbf{v} \cdotp \textbf{w}}{||\textbf{v}|| \ ||\textbf{w}||}$
# $=\frac{2(3)+1(-2)+5(6)}{\sqrt{2^{2}+1^{2}+5^{2}}\sqrt{3^{2}+(-2)^{2}+6^{2}}}$
# $=\frac{34}{7\sqrt{30}}$
#
# g. g. If $\beta$ is the angle between u and w, find cos$\beta$
# = cos$\beta$ = $\frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{u}|| \ ||\textbf{w}||}$
# $=\frac{1(3)+3(-2)-4(6)}{\sqrt{1^{2}+3^{2}+(-4)^{2}}\sqrt{3^{2}+(-2)^{2}+6^{2}}}$
# $=-\frac{27}{7\sqrt{26}}$
#
# h. Find d(u, v)
# d(u, v) = ||u - v|| = $\sqrt{(1-2)^2 + (3-1)^2 + ((-4)-5)^2} = \sqrt{1+4+81} = \sqrt{86}$
#
# i. Find d(w, v)
# d(w, v) = || w -v || = $\sqrt{(3-2)^2 + ((-2)-1)^2 + (6-5)^2} = \sqrt{1+9+1} = \sqrt{11}$
#
# j. Find d(u, w)
# d(u, w) = ||u - w|| = $\sqrt{(1-3)^2 + (3-(-2))^2 + ((-4)-6)^2} = \sqrt{4+25+100} = \sqrt{129}$
#
# k. Find proj(u, v)
# proj(u, v) = $\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{v}||^2} \textbf{v} = \frac{-15}{(\sqrt{30})^2}\begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix} =-\frac{1}{2}\begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix} = \begin{bmatrix}
#            -1 \\
#            -\frac{1}{2} \\
#            -\frac{5}{2}
#          \end{bmatrix}$
#
# l. Find proj(w, v)
# proj(w, v) = $\frac{\textbf{w} \cdotp \textbf{v}}{||\textbf{v}||^2} \textbf{v} = \frac{34}{(\sqrt{30})^2}\begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix} =\frac{17}{15}\begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix} = \begin{bmatrix}
#            \frac{34}{15} \\
#            \frac{17}{15} \\
#            \frac{17}{3}
#          \end{bmatrix}$
#
# m. Find proj(u, w)
# proj(u, w) = $\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{v}||^2} \textbf{v} = \frac{-27}{(7)^2}\begin{bmatrix}
#            3 \\
#            -2 \\
#            6
#          \end{bmatrix} =-\frac{27}{49}\begin{bmatrix}
#            3 \\
#            -2 \\
#            6
#          \end{bmatrix} = \begin{bmatrix}
#            -\frac{81}{49} \\
#            \frac{54}{49} \\
#            -\frac{162}{49}
#          \end{bmatrix}$

# %%
import numpy as np

u = np.array([1,3,-4])
v = np.array([2,1,5])
w = np.array([3,-2,6])

print("a. 3u - 2v = ", 3*u - 2*v)

print("b. 5u + 3v - 4w = ", 5*u + 3*v - 4*w)

print("c. u · v , v · w , u · w = ", u.dot(v),",", v.dot(w),",", u.dot(w))

print("d. ||u||, ||v||, ||w|| = ", np.sqrt(u.dot(u)),",", np.sqrt(v.dot(v)),",", np.sqrt(w.dot(w)))

print("e. cosθ = (u · v) =  ", u.dot(v) / (np.linalg.norm(u) * np.linalg.norm(v)))

print("f. cosα = (v · w) =  ", v.dot(w) / (np.linalg.norm(v) * np.linalg.norm(w)))

print("g. cosβ = (u · w) =  ", u.dot(w) / (np.linalg.norm(u) * np.linalg.norm(w)))

print("h. d(u,v) = ", np.linalg.norm(u-v))

print("i. d(w,v) = ", np.linalg.norm(w-v))

print("j. d(u,w) = ", np.linalg.norm(u-w))

print("k. proj(u,v) = ", u.dot(v)*v / (np.linalg.norm(v)**2))

print("l. proj(w,v) = ", w.dot(v)*v / (np.linalg.norm(v)**2))

print("m. proj(u,w) = ", u.dot(w)*w / (np.linalg.norm(w)**2))

# %% [markdown]
# 3. Let u = (2, -5, 4, 6, -3), v = (5, -2, 1, -7, -4) and w = (2, 1, -3)
#
# Manual:

# %% [markdown]
# a. 4u - 3v
# = 4(2, -5, 4, 6, -3) - 3(5, -2, 1, -7, -4)
# = (8, -20, 16, 24, -12) - (15, -6, 3, -21, -12)
# (-7, -14, 13, 45, 0)
#
# b. 5u + 2v - 2w
# = 5(2, -5, 4, 6, -3) + 2(5, -2, 1, -7, -4) - 2(2, 1, -3)
# = (10, -25, 20, 30, -15) + (10, -4, 2, -14, -6) - (4, 2, -6)
# = (16, -31, 28, 16, -23)
#
# c. u · v, v · w, u · w
# u · v = 2(5) + (-5)(-2) + 4(1) + 6(-7) + (-3)(-4) = -6
# v · w = 5(2) + (-2)(1) + 1(3) + (-7)(0) + (-4)0 = 5
# u · w = 2(2) + (-5)(1) + 4(-3) + 6(0) + (-3)0 = -13
#
# d. ||u||, ||v||, ||w||
# ||u|| = $\sqrt{u · u}$ = $\sqrt{2^{2}+(-5)^{2}+4^{2}+6^{2}+(-3)^{2}}$ = 3$\sqrt{10}$
# ||v|| = $\sqrt{v · v}$ = $\sqrt{5^{2}+(-2)^{2}+1^{2}+(-7)^{2}+(-4)^{2}}$ = $\sqrt{95}$
# ||w|| = $\sqrt{w · w}$ = $\sqrt{2^{2}+1^{2}+(-3)^{2}}$ = $\sqrt{14}$
#
# e. If $\theta$ is the angle between u and v, find cos$\theta$
# = cos$\theta$ = $\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}|| \ ||\textbf{v}||}$
# $=\frac{\textbf{u} \cdotp \textbf{v}}{||\textbf{u}|| \ ||\textbf{v}||}$
# $=-\frac{6}{3\sqrt{10}\sqrt{95}}$
#
# f. If $\alpha$ is the angle between v and w, find cos$\alpha$
# = cos$\alpha$ = $\frac{\textbf{v} \cdotp \textbf{w}}{||\textbf{v}|| \ ||\textbf{w}||}$
# $=\frac{\textbf{v} \cdotp \textbf{w}}{||\textbf{v}|| \ ||\textbf{w}||}$
# $=\frac{5}{\sqrt{95}\sqrt{14}}$
#
# g. g. If $\beta$ is the angle between u and w, find cos$\beta$
# = cos$\beta$ =$\frac{\textbf{u} \cdotp \textbf{w}}{||\textbf{u}|| \ ||\textbf{w}||}$
# $=-\frac{13}{3\sqrt{10}\sqrt{14}}$
#
# h. Find d(u, v)
# d(u, v) = ||u - v|| = $\sqrt{(2-5)^2 + ((-5)+2)^2 + (4-1)^2 + (6+7)^{2} + ((-3)+4)^{2}} = \sqrt{197}$
#
# i. Find d(w, v)
# d(w, v) = ||w - v|| = $\sqrt{(2-5)^2 + (1+2)^2 + ((-3)-1)^2 + (0+7)^{2} + (0+4)^{2}} = \sqrt{99}$
#
# j. Find d(u, w)
# d(u, w) = ||u - w|| = $\sqrt{(2-2)^2 + ((-5)-1)^2 + (4+3)^2 + (6-0)^{2} + (-3-0)^{2}} = \sqrt{130}$
#
# k. Find proj(u, v)
# proj(u, v) = (-$\frac{30}{94}, \frac{12}{95}, -\frac{6}{95}, \frac{42}{95}, \frac{24}{95})$
#
# l. Find proj(w, v)
# proj(w, v) = (-$\frac{5}{19}, \frac{-2}{19}, \frac{1}{19}, -\frac{7}{19}, -\frac{4}{19})$
#
# m. Find proj(u, w)
# proj(u, w) = (-$\frac{26}{14}, -\frac{13}{14}, \frac{39}{14}, 0, 0)$

# %%
Pythonic Solution:

# %%
import numpy as np

u = np.array([2,-5,4,6,-3])
v = np.array([5,-2,1,-7,-4])
w = np.array([2,1,-3,0,0])

print("a. 4u - 3v = ", 4*u - 3*v)

print("b. 5u + 2v - 2w = ", (5*u) + (2*v) - (2*w))

print("c. u.v , v.w , u.w = ", u.dot(v),",", v.dot(w),",", u.dot(w))

print("d. ||u||, ||v||, ||w|| = ", np.sqrt(u.dot(u)),",", np.sqrt(v.dot(v)),",", np.sqrt(w.dot(w)))

print("e. angle(u,v) cos θ = ", u.dot(v)/ (np.linalg.norm(u) * np.linalg.norm(v)))

print("f. angle(v,w) cos α = ", v.dot(w)/ (np.linalg.norm(v) * np.linalg.norm(w)))

print("g. angle(u,w) cos β = ", u.dot(w)/ (np.linalg.norm(u) * np.linalg.norm(w)))

print("h. d(u,v) = ", np.linalg.norm(u-v))

print("i. d(w,v) = ", np.linalg.norm(w-v))

print("j. d(u,w) = ", np.linalg.norm(u-w))

print("k. proj(u,v) = ", u.dot(v)*v / (np.linalg.norm(v)**2))

print("l. proj(w,v) = ", w.dot(v)*v / (np.linalg.norm(v)**2))

print("m. proj(u,w) = ", u.dot(w)*w / (np.linalg.norm(w)**2))

# %% [markdown]
# 4. Normalize each vector:

# %% [markdown]
# a. u = (5, -7)
# b. v = (1, 2, -2, 4)
# c. w = $(\frac{1}{2},\frac{-1}{3},\frac{3}{4})$
# Manual

# %% [markdown]
# a. ||u|| = $\sqrt{u · u} = \sqrt{5^{2}+(-7)^{2}} = \sqrt{25+49} = \sqrt{74}$  = u' = ($\frac{5}{\sqrt{74}, -\frac{7}{\sqrt{74})$
#
# b. ||v|| = $\frac{v}{||v||} = (\frac{1}{5}, \frac{2}{5}, -\frac{2}{5}, \frac{4}{5})$
#
# c. ||w|| = $\frac{w}{||w||} = (\frac{\frac{1}{2}}{\sqrt{\frac{133}{144}}}, \frac{\frac{-1}{3}}{\sqrt{\frac{133}{144}}}, \frac{\frac{3}{4}}{\sqrt{\frac{133}{144}}})$

# %% [markdown]
# Pythonic Solution

# %%
import numpy as np

u = np.array([5,-7])
v = np.array([1,2,-2,4])
w = np.array([1/2,-1/3,3/4])

print("||u||' = ", u / np.sqrt(u.dot(u)))
print("||v||' = ", v / np.sqrt(v.dot(v)))
print("||w||' = ", w / np.sqrt(w.dot(w)))

# %% [markdown]
# 5. Let u = (1, 2, -2), v = (3, -12, 4) and a scalar k = -3
#
# Find ||u||, ||v||, ||u + v||, ||ku||
#
# Manual:

# %% [markdown]
# ||u|| = $\sqrt{u · u} = \sqrt{1^{2}+(2)^{2}+(-2)^{2}} = \sqrt{1+4+4} = 3$
# ||v|| = $\sqrt{v · v} = \sqrt{3^{2}+(-12)^{2}+(4)^{2}} = \sqrt{9+144+16} = 13$
#
# ||u + v||
# u + v = (1, 2 -2) + (3, -12, 4) = (4, -10, 2)
# ||u + v|| = = $\sqrt{16+100+4} = \sqrt{120} = 2\sqrt{30}$
#
# ||ku|| => ku = (-3, -6, 6)
# = $=\sqrt{9 + 36 + 36} = \sqrt{81} = 9$

# %% [markdown]
# Pythonic Solution

# %%
import numpy as np

u = np.array([1,2,-2])
v = np.array([3,-12,4])
k = -3

print("||u|| = ", np.sqrt(u.dot(u)))

print("||v|| = ", np.sqrt(v.dot(v)))

print("||u + v|| = ", np.linalg.norm(u+v))

print("||ku|| = ", np.linalg.norm(k*u))

# %% [markdown]
# 6. Find k so that u and v are orthogonal
# Manual Solution

# %% [markdown]
# a. u = (3, k, -2), v = (6, -4, -3)
# u · v =
# 18 - 4k + 6 = 0
# -4k = -24
# k = 6
#
# b. u = (5, k, -4, 2), v = (1, -3, 2, 2k)
# u · v =
# 5 - 3k -8 + 4k = 0
# -3 + k = 0
# k = 3
#
# c. u = (1, 7, k + 2, -2), v = (3, k, -3, k)
# u · v =
# 3 + 7k -3k -6 -2k = 0
# 2k - 3 = 0
# 2k = 3
# k = $\frac{3}2$

# %%
import numpy as np
from sympy import symbols, solve
k = symbols('k')

print("a. k = ", solve(18-4*k+6))

print("b. k = ", solve(5-k*3-8+4*k))

print("c.  k = ", solve(3+6*k-3*k-2*k))
